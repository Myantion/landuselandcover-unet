# %%
# !pip install gdown
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.11.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)

# %%
# 确定下载链接和文件名
DIRECT_LINK = "https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/0d67e451-6388-462f-bb51-36d506b4865c"
OUTPUT_FILENAME = "sen2_lulc_data.zip" # 假设是 zip 格式

print(f"开始使用 wget 下载数据集 ({OUTPUT_FILENAME}) 到 /content/ ...")
# 使用 wget 下载文件，-O 指定输出文件名
# !wget -O {OUTPUT_FILENAME} {DIRECT_LINK}

print("--- 下载完成 ---")
# Out:
# 开始使用 wget 下载数据集 (sen2_lulc_data.zip) 到 /content/ ...
# --2025-11-27 10:49:12--  https://prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com/0d67e451-6388-462f-bb51-36d506b4865c
# Resolving prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com)... 52.92.19.146, 3.5.67.254, 52.92.32.178, ...
# Connecting to prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com (prod-dcd-datasets-public-files-eu-west-1.s3.eu-west-1.amazonaws.com)|52.92.19.146|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2445753004 (2.3G) [application/zip]
# Saving to: ‘sen2_lulc_data.zip’
#
# sen2_lulc_data.zip  100%[===================>]   2.28G  25.9MB/s    in 93s
#
# 2025-11-27 10:50:46 (25.1 MB/s) - ‘sen2_lulc_data.zip’ saved [2445753004/2445753004]
#
# --- 下载完成 ---

# %%
OUTPUT_FILENAME = "sen2_lulc_data.zip"
UNZIPPED_FOLDER = "/content/sen2_lulc_raw/"

print(f"开始解压 {OUTPUT_FILENAME} 到 {UNZIPPED_FOLDER} ...")
# 创建目标文件夹并解压
# !mkdir -p {UNZIPPED_FOLDER}
# !unzip {OUTPUT_FILENAME} -d {UNZIPPED_FOLDER}

print("--- 解压完成 ---")
# 打印解压后文件夹中的前几个文件（可选，用于验证）
# !ls {UNZIPPED_FOLDER} | head -n 5
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/11303.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/113060.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/113219.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/113317.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/113344.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/114018.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/114097.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/114196.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/1143.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/114649.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/114777.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/115130.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/115462.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/115466.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/115554.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/115678.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/115846.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/116043.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/116445.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/116787.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/116913.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/116986.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/117092.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/117661.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/117796.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/118038.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/11821.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/118554.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/118575.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/118948.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/119313.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/119319.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/119456.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/119523.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/119673.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/119739.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/120097.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/121324.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/121496.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/121681.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/122729.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/122766.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/123071.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/123140.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/123821.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/123977.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/124492.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/124587.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/12478.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/124894.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/124983.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/125089.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/125149.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/12521.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/125619.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/125636.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/125694.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/125771.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/126383.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/126442.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/126546.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/126853.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/126866.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/126888.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/127051.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/127075.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/12731.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/12732.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/127447.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/127491.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/127499.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/127771.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/128343.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/128397.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/128419.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/128482.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/128511.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/128641.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/128642.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/128663.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/129129.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/129145.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/129600.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/129778.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/129847.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/129961.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/129993.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/130332.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/130664.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/13121.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/131551.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/131656.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/132280.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/132384.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/132525.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/132554.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/132586.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/132676.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/132899.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/132928.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/132929.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/133390.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/133643.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/133664.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/134328.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/134384.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/134463.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/134475.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/134486.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/135403.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/135798.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/135841.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/13598.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/136132.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/136376.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/136454.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/136779.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/136824.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/136937.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/137122.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/137149.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/137397.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/137808.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/138001.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/138053.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/13878.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/139193.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/139520.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/139984.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/140213.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/140402.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/140539.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/140762.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/140816.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/140906.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/14095.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/141110.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/141274.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/141354.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/141592.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/141595.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/141707.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/141813.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/141871.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/141895.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142085.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142193.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/1422.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142290.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142347.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142612.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142672.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142730.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142789.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/143294.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/143603.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/143645.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/143717.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/143842.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/143923.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/144058.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/144523.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/144622.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/144746.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/144804.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/145642.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/145806.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/14589.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/146021.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/146111.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/146140.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/146194.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/146578.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/146741.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/146761.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/147185.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/147277.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/147325.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/147370.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/147940.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/147978.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/148114.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/148791.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/14901.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149089.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149165.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149176.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149312.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149378.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149412.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149671.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149679.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149708.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149728.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149765.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149774.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/149783.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/15.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/150350.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/150852.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/150951.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/151056.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/151441.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/151710.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/152063.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/152366.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/152718.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/152829.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/153058.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/15347.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/153627.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/15385.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/153889.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/15405.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/154129.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/15425.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/154406.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/154439.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/154465.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/154668.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/154980.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/155176.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/155300.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/156.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/156046.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/156409.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/156468.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/156492.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/156921.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/156970.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/157074.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/157237.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/157269.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/157981.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/158020.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/158805.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/159385.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/159443.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/159683.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/160247.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/160369.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/16053.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/160857.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/160982.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/161057.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/161062.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/161325.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/16170.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/161710.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/161920.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/162446.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/162492.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/16265.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/162989.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/163045.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/16329.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/163386.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/16356.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/163758.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/164022.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/164463.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/164876.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/164889.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/165074.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/165604.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/165877.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/166083.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/166223.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/16653.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/166738.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/166938.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167200.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167214.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167232.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167305.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167527.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167676.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167722.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167822.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/168793.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/169425.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/16959.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/169876.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/170211.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/170245.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/170250.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/170443.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/170577.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/171705.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/17195.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/172232.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/172263.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/172787.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/172797.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/173149.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/174030.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/174184.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/174420.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/174421.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/174839.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/175172.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/175246.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/17536.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/175894.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/176188.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/176332.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/176360.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/176499.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/1768.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/176996.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/177822.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/177824.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/177884.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/178269.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/178284.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/178366.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/178625.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/178642.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/17879.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/178916.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/178938.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/179359.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/179569.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/179673.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/179814.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/179888.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/180015.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/180569.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/180685.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/180796.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/180808.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/180834.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/180892.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/181257.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/181376.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/181393.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/181455.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/181498.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/181674.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/181906.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/181920.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/182178.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/182653.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/183180.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/183593.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/183641.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/183857.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/184040.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/184129.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/185018.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/185464.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/185469.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/18547.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/18601.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/186286.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/1867.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/186818.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/187262.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/187302.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/187348.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/187440.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/18832.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/188436.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/188810.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/188912.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/189441.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/189506.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/189553.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/18959.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/189916.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/18995.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/190192.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/190467.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/190544.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/190587.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/190627.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/190681.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/19069.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/190978.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/191032.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/191043.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/191234.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/191450.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/191518.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/191625.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/191857.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/19208.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/192108.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/19224.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/192250.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/192478.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/192644.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/19273.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/192844.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/19324.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/193260.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/193365.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/193477.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/193504.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/193709.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/193745.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/193856.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/193980.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/194161.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/194236.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/194259.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/194300.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/194703.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/194882.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/194895.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/195451.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/19566.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/196026.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/196591.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/196806.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/197069.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/197211.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/19723.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/197246.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/197323.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/197580.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/19759.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/197751.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/198143.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/198756.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/198831.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/199030.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/199097.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/19916.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/199199.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/199524.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/199605.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/199635.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/199957.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/200118.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/200300.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/200341.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/200344.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/200459.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/200513.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/200685.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/200721.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/20074.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/201076.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/201470.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/20154.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/201978.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/202009.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/202037.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/202055.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/20208.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/202260.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/202339.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/202498.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/202790.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/202808.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203082.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203427.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203437.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203506.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203625.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203628.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/20365.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203686.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203704.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/20384.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203853.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/204341.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/204958.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/205206.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/205247.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/205314.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/205393.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/20610.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/2062.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/206489.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/206500.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/206939.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/207062.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/207122.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/207155.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/207265.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/207387.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/207519.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/2077.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/207893.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/208281.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/208349.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/208427.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/20878.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/208791.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/208838.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/208961.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/209280.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/209506.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/209699.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/20972.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/209751.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/210274.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/210460.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/210588.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/210693.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/210773.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/210971.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/211201.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/211682.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/21173.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/212102.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/212139.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/212249.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/212342.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/21256.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/212927.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/213511.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/21848.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/21885.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/22758.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/22946.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/22993.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/23525.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/23779.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/23932.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/24530.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/24798.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/24867.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/24899.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/25099.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/25114.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/25265.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/25344.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/25438.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/25489.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/26009.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/26033.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/26039.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/2605.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/26365.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/26486.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/26560.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/26849.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/26921.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/27351.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/27903.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/28166.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/28710.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/29046.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/29050.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/29219.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/29316.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/29349.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/2979.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/29924.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/31093.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/3145.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/31543.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/31607.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/31685.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/31791.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/31803.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/32105.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/32158.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/32394.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/3283.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/33551.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/33947.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/34093.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/34169.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/34556.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/34577.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/34863.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/3493.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/34948.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/35087.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/35172.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/35577.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/35635.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/35962.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/35989.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/36175.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/36186.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/36201.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/3655.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/36630.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/36640.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/36851.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/37005.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/3710.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/37227.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/37464.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/37542.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/37552.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/37849.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/38151.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/38465.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/38471.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/38615.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/38618.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/38920.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/38966.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/39223.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/39326.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/39431.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/39517.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/39746.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/3976.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/39816.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/40021.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/4005.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/40500.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/40548.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/40693.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/4076.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/40849.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/41018.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/4115.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/41741.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/4203.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/42388.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/42414.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/42920.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/43140.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/43386.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/43637.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/43674.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/43683.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/43760.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/44124.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/44446.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/44628.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/44704.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/44745.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/44964.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/4506.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/45123.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/45236.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/45549.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/45874.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/45988.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/46052.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/46184.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/46222.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/46231.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/46246.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/46538.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/4658.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/46915.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/47255.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/47331.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/47355.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/47640.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/47732.tif
# ...
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/74246.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/74974.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/74991.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/75028.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/75221.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/75342.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/75347.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/75622.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/75648.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/75855.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/76107.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/76243.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/76390.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/76609.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/77406.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/77680.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/77764.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/77956.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/78355.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/78580.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/78691.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/79073.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/79107.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/79187.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/79304.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/79318.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/79521.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/79636.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/7995.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/79966.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/80006.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/80090.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/80129.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/80158.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/80706.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/80759.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/8100.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/81322.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/81620.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/8172.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/81938.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/82064.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/82097.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/82601.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/82686.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/8280.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/83027.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/83157.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/83164.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/83325.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/83618.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/84482.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/84497.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/8515.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/85165.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/85265.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/85270.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/8540.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/85760.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/86093.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/8641.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/86495.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/86726.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/87022.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/87256.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/8731.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/87329.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/87473.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/87586.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/87637.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/88014.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/8804.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/88215.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/88242.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/88612.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/89063.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/89535.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/89666.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/89870.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/89889.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/90001.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/90067.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/90399.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/90680.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/90718.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/90784.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/90958.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/9114.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/91226.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/91263.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/91341.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/91444.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/91533.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/91756.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/91976.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/92282.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/92392.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/92618.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/92791.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/92794.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/92839.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/92922.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/93555.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/93675.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/93877.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/94335.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/94470.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/94553.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/94853.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/94952.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/95400.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/95463.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/95518.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/95820.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/95852.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/95928.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/95942.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/95943.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/96047.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/96052.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/96357.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/96521.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/96794.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/96883.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/97438.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/97776.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/97877.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/98087.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/98142.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/98652.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/98744.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/98752.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/98768.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/9903.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/99076.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/99252.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/99329.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/99346.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/99987.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/103989.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/106278.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/110041.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/11184.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/113996.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/114526.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/119371.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/126617.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/129227.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/1320.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/133067.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/13369.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/134314.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/136794.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/138318.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142504.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/142729.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/14382.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/153497.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/154205.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/160716.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/161321.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/162676.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/163033.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/165445.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167223.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/167708.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/168799.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/169156.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/172311.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/172777.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/177763.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/181566.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/183844.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/186180.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/186607.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/188530.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/18973.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/193835.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/194189.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/195137.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/195945.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/197520.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/197978.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/202618.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/203623.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/204846.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/206678.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/22354.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/23413.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/2665.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/27268.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/28262.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/28538.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/3153.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/31805.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/33680.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/34248.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/34813.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/36457.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/44343.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/49621.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/51172.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/52588.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/54125.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/61023.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/64376.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/64627.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/65354.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/67399.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/74373.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/77684.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/80159.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/81248.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/82113.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/82864.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/83466.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/88050.tif
#   inflating: /content/sen2_lulc_raw/SEN-2 LULC/val_masks/val/9888.tif
# --- 解压完成 ---

# %%
# --- 0. 挂载 Google Drive 并安装依赖 ---
from google.colab import drive
import os

# 挂载您的 Google Drive
print("请在弹出的窗口中授权 Google Drive 挂载...")
drive.mount('/content/drive')
# 确保目标保存路径存在
WEIGHTS_SAVE_DIR = '/content/drive/MyDrive/LULC_Pretrain_Weights'
if not os.path.exists(WEIGHTS_SAVE_DIR):
    os.makedirs(WEIGHTS_SAVE_DIR)
print(f"权重将保存到 Drive 路径: {WEIGHTS_SAVE_DIR}")

# 必须安装的库
# !pip install rasterio opencv-python

import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
import glob
import rasterio
import cv2

# 启用 AUTOTUNE
AUTOTUNE = tf.data.AUTOTUNE

# --- 1. 全局配置与参数 (关键修改在这里) ---
IMG_HEIGHT = 64
IMG_WIDTH = 64
NUM_BANDS = 3
NUM_CLASSES = 7
INPUT_SHAPE = (IMG_HEIGHT, IMG_WIDTH, NUM_BANDS)

GLOBAL_MIN = 0.0
GLOBAL_MAX = 255.0

# 🚨 关键修改：减少到 8 个 Epoch
EPOCHS = 8
BATCH_SIZE = 16
LEARNING_RATE = 1e-4

# 权重保存到 Drive
MODEL_WEIGHTS_PATH = os.path.join(WEIGHTS_SAVE_DIR, 'best_lulc_pretrained_weights.h5')

# --- 数据集目录配置 (路径保持不变) ---
BASE_RAW_DIR = "/content/sen2_lulc_raw/SEN-2 LULC/"
TRAIN_IMG_DIR = os.path.join(BASE_RAW_DIR, 'train_images', 'train')
TRAIN_MASK_DIR = os.path.join(BASE_RAW_DIR, 'train_masks', 'train')
VAL_IMG_DIR = os.path.join(BASE_RAW_DIR, 'val_images', 'val')
VAL_MASK_DIR = os.path.join(BASE_RAW_DIR, 'val_masks', 'val')


# --- 2. 辅助函数 (保持不变) ---

def global_normalize(img: np.ndarray, global_min: float, global_max: float) -> np.ndarray:
    if global_max == global_min:
        return img.astype(np.float32)
    img_norm = (img - global_min) / (global_max - global_min)
    return np.clip(img_norm, 0.0, 1.0).astype(np.float32)

def create_lulc_paths(img_dir, mask_dir):
    img_files = glob.glob(os.path.join(img_dir, '*.png'))
    patch_paths = []
    for img_path in img_files:
        file_id = os.path.basename(img_path).split('.')[0]
        mask_path = os.path.join(mask_dir, f"{file_id}.tif")
        if os.path.exists(mask_path):
            patch_paths.append((img_path, mask_path))
    return patch_paths


# --- 3. 模型组件 (U-Net) (已修正) ---

def conv_block(input_tensor, num_filters, kernel_size=(3, 3)):
    x = layers.Conv2D(num_filters, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Conv2D(num_filters, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same')(x)
    x = layers.BatchNormalization()(x)
    return x

def encoder_block(input_tensor, num_filters):
    x = conv_block(input_tensor, num_filters)
    p = layers.MaxPooling2D((2, 2))(x)
    return x, p

def decoder_block(input_tensor, skip_tensor, num_filters):
    x = layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
    x = layers.concatenate([x, skip_tensor])
    x = conv_block(x, num_filters)
    return x

def build_lulc_unet(input_shape, num_classes):
    inputs = layers.Input(input_shape)

    c1, p1 = encoder_block(inputs, 32)
    c2, p2 = encoder_block(p1, 64)
    c3, p3 = encoder_block(p2, 128)
    c4, p4 = encoder_block(p3, 256)

    b = conv_block(p4, 512)

    u4 = decoder_block(b, c4, 256)
    u3 = decoder_block(u4, c3, 128)
    u2 = decoder_block(u3, c2, 64)
    u1 = decoder_block(u2, c1, 32) # 修正：输入是 u2

    outputs = layers.Conv2D(num_classes, (1, 1), activation='softmax')(u1)

    model = Model(inputs=[inputs], outputs=outputs)
    return model


# --- 4. tf.data 管道 (保持不变) ---

@tf.function(input_signature=[
    tf.TensorSpec(None, tf.string),
    tf.TensorSpec(None, tf.string)
])
def load_patch_data_wrapper(img_fp_tensor, mask_fp_tensor):
    def load_numpy_arrays(img_fp, mask_fp):
        img_fp_str = img_fp.numpy().decode('utf-8')
        mask_fp_str = mask_fp.numpy().decode('utf-8')

        img = cv2.imread(img_fp_str, cv2.IMREAD_COLOR)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

        with rasterio.open(mask_fp_str) as src:
            label_int = src.read(1)

        X = global_normalize(img.astype(np.float32), GLOBAL_MIN, GLOBAL_MAX)
        label_clipped = np.clip(label_int, 0, NUM_CLASSES - 1).astype(np.int32)
        Y = tf.keras.utils.to_categorical(label_clipped, num_classes=NUM_CLASSES)

        return X.astype(np.float32), Y.astype(np.float32)

    return tf.py_function(
        load_numpy_arrays,
        [img_fp_tensor, mask_fp_tensor],
        [tf.float32, tf.float32]
    )

def create_dataset(patch_files, batch_size, is_training):
    img_paths = [p[0] for p in patch_files]
    mask_paths = [p[1] for p in patch_files]

    dataset = tf.data.Dataset.from_tensor_slices((img_paths, mask_paths))

    if is_training:
        dataset = dataset.shuffle(buffer_size=min(len(patch_files), 10000))

    dataset = dataset.map(
        load_patch_data_wrapper,
        num_parallel_calls=AUTOTUNE
    )

    dataset = dataset.map(lambda x, y: (
        tf.ensure_shape(x, INPUT_SHAPE),
        tf.ensure_shape(y, (IMG_HEIGHT, IMG_WIDTH, NUM_CLASSES))
    ), num_parallel_calls=AUTOTUNE)

    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(AUTOTUNE)

    return dataset


# --- 5. 主训练函数 ---

def run_lulc_pretraining():
    print("--- 阶段 I: 数据加载器准备 (tf.data Pipeline) ---")

    train_patch_files = create_lulc_paths(TRAIN_IMG_DIR, TRAIN_MASK_DIR)
    val_patch_files = create_lulc_paths(VAL_IMG_DIR, VAL_MASK_DIR)

    if not train_patch_files or not val_patch_files:
        print("❌ 错误：无法找到足够的训练或验证切片。")
        return

    train_dataset = create_dataset(train_patch_files, BATCH_SIZE, is_training=True)
    val_dataset = create_dataset(val_patch_files, BATCH_SIZE, is_training=False)

    print(f"训练样本总数: {len(train_patch_files)}, 验证样本总数: {len(val_patch_files)}")

    print("\n--- 阶段 II: 模型构建与编译 ---")

    model = build_lulc_unet(INPUT_SHAPE, NUM_CLASSES)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss='categorical_crossentropy',
        metrics=['accuracy', tf.keras.metrics.MeanIoU(num_classes=NUM_CLASSES)]
    )

    model_checkpoint_callback = ModelCheckpoint(
        filepath=MODEL_WEIGHTS_PATH,
        monitor='val_mean_io_u',
        mode='max',
        save_best_only=True,
        save_freq='epoch',
        verbose=1
    )
    # 8个Epoch太少，不再设置 Early Stopping

    print(f"模型权重将保存到: {MODEL_WEIGHTS_PATH}")

    print(f"\n--- 阶段 III: 开始 LULC 预训练 (目标: {EPOCHS} 个 Epoch, 使用 GPU 加速抢跑) ---")

    # 检查是否有之前保存的权重，如果有，从那里继续
    if os.path.exists(MODEL_WEIGHTS_PATH):
        model.load_weights(MODEL_WEIGHTS_PATH)
        print(f"✅ 从 Drive 加载了上次的最佳权重，将从这里继续训练。")

    model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=[model_checkpoint_callback],
        verbose=1
    )

    print("\n--- LULC 预训练完成 ---")

    model.load_weights(MODEL_WEIGHTS_PATH)
    print(f"最佳模型权重已从 Drive 加载: {MODEL_WEIGHTS_PATH}")

    return model

# --- 6. 启动执行 ---
if __name__ == '__main__':
    model = run_lulc_pretraining()
# Out:
# 请在弹出的窗口中授权 Google Drive 挂载...
# Mounted at /content/drive
# 权重将保存到 Drive 路径: /content/drive/MyDrive/LULC_Pretrain_Weights
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (1.4.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio) (25.4.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio) (2025.11.12)
# Requirement already satisfied: click>=4.0 in /usr/local/lib/python3.12/dist-packages (from rasterio) (8.3.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from rasterio) (2.0.2)
# Requirement already satisfied: click-plugins in /usr/local/lib/python3.12/dist-packages (from rasterio) (1.1.1.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio) (3.2.5)
# --- 阶段 I: 数据加载器准备 (tf.data Pipeline) ---
# 训练样本总数: 149600, 验证样本总数: 32079
#
# --- 阶段 II: 模型构建与编译 ---
# 模型权重将保存到: /content/drive/MyDrive/LULC_Pretrain_Weights/best_lulc_pretrained_weights.h5
#
# --- 阶段 III: 开始 LULC 预训练 (目标: 8 个 Epoch, 使用 GPU 加速抢跑) ---
# Epoch 1/8
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6346 - loss: 1.0673 - mean_io_u: 0.4286
# Epoch 1: val_mean_io_u improved from -inf to 0.42857, saving model to /content/drive/MyDrive/LULC_Pretrain_Weights/best_lulc_pretrained_weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 1280s 134ms/step - accuracy: 0.6346 - loss: 1.0673 - mean_io_u: 0.4286 - val_accuracy: 0.7331 - val_loss: 0.6420 - val_mean_io_u: 0.4286
# Epoch 2/8
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.7296 - loss: 0.6442 - mean_io_u: 0.4286
# Epoch 2: val_mean_io_u did not improve from 0.42857
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 1200s 128ms/step - accuracy: 0.7296 - loss: 0.6442 - mean_io_u: 0.4286 - val_accuracy: 0.7704 - val_loss: 0.5460 - val_mean_io_u: 0.4286
# Epoch 3/8
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.7611 - loss: 0.5676 - mean_io_u: 0.4286
# Epoch 3: val_mean_io_u improved from 0.42857 to 0.42857, saving model to /content/drive/MyDrive/LULC_Pretrain_Weights/best_lulc_pretrained_weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 1183s 127ms/step - accuracy: 0.7611 - loss: 0.5676 - mean_io_u: 0.4286 - val_accuracy: 0.7923 - val_loss: 0.4915 - val_mean_io_u: 0.4286
# Epoch 4/8
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.7804 - loss: 0.5221 - mean_io_u: 0.4289
# Epoch 4: val_mean_io_u improved from 0.42857 to 0.42858, saving model to /content/drive/MyDrive/LULC_Pretrain_Weights/best_lulc_pretrained_weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 1219s 130ms/step - accuracy: 0.7804 - loss: 0.5221 - mean_io_u: 0.4289 - val_accuracy: 0.8031 - val_loss: 0.4713 - val_mean_io_u: 0.4286
# Epoch 5/8
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.7947 - loss: 0.4883 - mean_io_u: 0.4293
# Epoch 5: val_mean_io_u improved from 0.42858 to 0.42867, saving model to /content/drive/MyDrive/LULC_Pretrain_Weights/best_lulc_pretrained_weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 1243s 133ms/step - accuracy: 0.7947 - loss: 0.4883 - mean_io_u: 0.4293 - val_accuracy: 0.8112 - val_loss: 0.4496 - val_mean_io_u: 0.4287
# Epoch 6/8
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8052 - loss: 0.4645 - mean_io_u: 0.4296
# Epoch 6: val_mean_io_u did not improve from 0.42867
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 1180s 126ms/step - accuracy: 0.8052 - loss: 0.4645 - mean_io_u: 0.4296 - val_accuracy: 0.7984 - val_loss: 0.4814 - val_mean_io_u: 0.4286
# Epoch 7/8
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.8149 - loss: 0.4418 - mean_io_u: 0.4300
# Epoch 7: val_mean_io_u improved from 0.42867 to 0.42874, saving model to /content/drive/MyDrive/LULC_Pretrain_Weights/best_lulc_pretrained_weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 1182s 126ms/step - accuracy: 0.8150 - loss: 0.4418 - mean_io_u: 0.4300 - val_accuracy: 0.8210 - val_loss: 0.4285 - val_mean_io_u: 0.4287
# Epoch 8/8
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.8229 - loss: 0.4224 - mean_io_u: 0.4305
# Epoch 8: val_mean_io_u improved from 0.42874 to 0.42882, saving model to /content/drive/MyDrive/LULC_Pretrain_Weights/best_lulc_pretrained_weights.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 9350/9350 ━━━━━━━━━━━━━━━━━━━━ 1173s 125ms/step - accuracy: 0.8229 - loss: 0.4224 - mean_io_u: 0.4305 - val_accuracy: 0.8233 - val_loss: 0.4220 - val_mean_io_u: 0.4288
#
# --- LULC 预训练完成 ---
# 最佳模型权重已从 Drive 加载: /content/drive/MyDrive/LULC_Pretrain_Weights/best_lulc_pretrained_weights.h5

# %%
# 1. 确保 gdown 已安装
# !pip install gdown

# 2. 定义下载参数
FILE_ID = '1QlAdzrHpfBIOZ6SK78yHF2i1u6tikmBc'
OUTPUT_FILENAME = 'SECOND_dataset.zip'
DOWNLOAD_DIR = '/content/SECOND_data'

# 3. 创建目标文件夹
import os
if not os.path.exists(DOWNLOAD_DIR):
    os.makedirs(DOWNLOAD_DIR)

OUTPUT_PATH = os.path.join(DOWNLOAD_DIR, OUTPUT_FILENAME)

print(f"开始下载 SECOND 数据集到: {OUTPUT_PATH}")

# 4. 执行下载
# !gdown --id $FILE_ID -O $OUTPUT_PATH

# 5. 解压文件 (假设它是一个 zip 文件)
print("\n开始解压文件...")
# !unzip -q $OUTPUT_PATH -d $DOWNLOAD_DIR

print("\n🎉 SECOND 数据集下载和解压完成！")
print(f"数据现在位于 {DOWNLOAD_DIR} 目录下，请检查其内部结构。")

# 可选：检查解压后的文件列表
# print("目录内容预览:")
# !ls -F $DOWNLOAD_DIR
# Out:
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (5.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown) (3.20.0)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.12/dist-packages (from gdown) (2.32.4)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from gdown) (4.67.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (2.8)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (2025.11.12)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown) (1.7.1)
# 开始下载 SECOND 数据集到: /content/SECOND_data/SECOND_dataset.zip
# /usr/local/lib/python3.12/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From (original): https://drive.google.com/uc?id=1QlAdzrHpfBIOZ6SK78yHF2i1u6tikmBc
# From (redirected): https://drive.google.com/uc?id=1QlAdzrHpfBIOZ6SK78yHF2i1u6tikmBc&confirm=t&uuid=bfc75e1f-f9e8-43b1-a02f-8493b628a36a
# To: /content/SECOND_data/SECOND_dataset.zip
# 100% 2.41G/2.41G [00:23<00:00, 101MB/s]
#
# 开始解压文件...
# [/content/SECOND_data/SECOND_dataset.zip]
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of /content/SECOND_data/SECOND_dataset.zip or
#         /content/SECOND_data/SECOND_dataset.zip.zip, and cannot find /content/SECOND_data/SECOND_dataset.zip.ZIP, period.
#
# 🎉 SECOND 数据集下载和解压完成！
# 数据现在位于 /content/SECOND_data 目录下，请检查其内部结构。

# %%
# 安装 unrar 工具
print("安装 unrar 工具...")
# !apt-get install unrar
# Out:
# 安装 unrar 工具...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# unrar is already the newest version (1:6.1.5-1ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.

# %%
# 使用 unrar 工具解压文件
RAR_FILE = '/content/SECOND_data/SECOND_dataset.zip'
OUTPUT_DIR = '/content/SECOND_data/'

print(f"开始解压 RAR 文件: {RAR_FILE}...")
# -x: 提取文件，-o+: 覆盖现有文件（如果存在），-d: 目标目录
# !unrar x $RAR_FILE $OUTPUT_DIR

print("\n🎉 SECOND 数据集已成功解压！")
print("现在数据已准备好用于变化检测模型的微调。")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/SECOND_data/im2                                  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# All OK
#
# 🎉 SECOND 数据集已成功解压！
# 现在数据已准备好用于变化检测模型的微调。

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.callbacks import ModelCheckpoint
import glob
import os
import cv2
import sys

# 启用 AUTOTUNE
AUTOTUNE = tf.data.AUTOTUNE

# --- 0. 挂载 Google Drive 和路径配置 ---
try:
    from google.colab import drive
    drive.mount('/content/drive')
    print("✅ Google Drive 挂载成功。")
except ImportError:
    print("❌ 无法在当前环境中挂载 Google Drive。请确保在 Colab 中运行。")

# LULC 预训练的权重路径 (请检查您的 Drive 路径)
LULC_WEIGHTS_PATH = '/content/drive/MyDrive/LULC_Pretrain_Weights/best_lulc_pretrained_weights.h5'
# SECOND 数据集的根目录 (由前面的解压步骤创建)
SECOND_DATA_ROOT = '/content/SECOND_data/'

# --- 1. 全局配置与参数 ---
IMG_HEIGHT = 512
IMG_WIDTH = 512
NUM_BANDS = 3
INPUT_SHAPE = (IMG_HEIGHT, IMG_WIDTH, NUM_BANDS)

# 最终变化检测的输出类别数： 4 类
NUM_CHANGE_CLASSES = 4

# 🚨 Epochs 安全策略：10 个 Epoch
EPOCHS = 25
BATCH_SIZE = 4
LEARNING_RATE = 1e-5

# T1 和 T2 图像/标签路径
IM1_DIR = os.path.join(SECOND_DATA_ROOT, 'im1')
IM2_DIR = os.path.join(SECOND_DATA_ROOT, 'im2')
LABEL1_DIR = os.path.join(SECOND_DATA_ROOT, 'label1')
LABEL2_DIR = os.path.join(SECOND_DATA_ROOT, 'label2')

CD_WEIGHTS_PATH = os.path.join(os.path.dirname(LULC_WEIGHTS_PATH), 'best_cd_finetune_weights.h5')


# --- 2. U-Net 辅助函数 (保持不变) ---

def conv_block(input_tensor, num_filters, kernel_size=(3, 3), name_suffix=''):
    x = layers.Conv2D(num_filters, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same', name=f'conv_{num_filters}_a{name_suffix}')(input_tensor)
    x = layers.BatchNormalization(name=f'bn_{num_filters}_a{name_suffix}')(x)
    x = layers.Conv2D(num_filters, kernel_size, activation='relu', kernel_initializer='he_normal', padding='same', name=f'conv_{num_filters}_b{name_suffix}')(x)
    x = layers.BatchNormalization(name=f'bn_{num_filters}_b{name_suffix}')(x)
    return x

def encoder_block(input_tensor, num_filters, name_prefix):
    x = conv_block(input_tensor, num_filters, name_suffix=f'_{name_prefix}')
    p = layers.MaxPooling2D((2, 2), name=f'pool_{num_filters}_{name_prefix}')(x)
    return x, p

def decoder_block(input_tensor, skip_tensor, num_filters):
    x = layers.Conv2DTranspose(num_filters, (2, 2), strides=(2, 2), padding='same')(input_tensor)
    x = layers.concatenate([x, skip_tensor])
    x = conv_block(x, num_filters)
    return x

# --- 3. Pseudo-Siamese U-Net 模型构建 (已修复命名冲突) ---

def build_pseudo_siamese_unet(input_shape, num_change_classes):
    input_t1 = layers.Input(input_shape, name='input_t1')
    input_t2 = layers.Input(input_shape, name='input_t2')

    c1_t1, p1_t1 = encoder_block(input_t1, 32, 't1')
    c2_t1, p2_t1 = encoder_block(p1_t1, 64, 't1')
    c3_t1, p3_t1 = encoder_block(p2_t1, 128, 't1')
    c4_t1, p4_t1 = encoder_block(p3_t1, 256, 't1')

    c1_t2, p1_t2 = encoder_block(input_t2, 32, 't2')
    c2_t2, p2_t2 = encoder_block(p1_t2, 64, 't2')
    c3_t2, p3_t2 = encoder_block(p2_t2, 128, 't2')
    c4_t2, p4_t2 = encoder_block(p3_t2, 256, 't2')

    # 🚨 命名修正：确保瓶颈层名称唯一
    b_t1 = conv_block(p4_t1, 512, name_suffix='_bottleneck_t1')
    b_t2 = conv_block(p4_t2, 512, name_suffix='_bottleneck_t2')

    bottleneck_diff = layers.Subtract(name='bottleneck_diff')([b_t1, b_t2])

    diff_c4 = layers.Subtract(name='skip_diff_c4')([c4_t1, c4_t2])
    diff_c3 = layers.Subtract(name='skip_diff_c3')([c3_t1, c3_t2])
    diff_c2 = layers.Subtract(name='skip_diff_c2')([c2_t1, c2_t2])
    diff_c1 = layers.Subtract(name='skip_diff_c1')([c1_t1, c1_t2])

    u4 = decoder_block(bottleneck_diff, diff_c4, 256)
    u3 = decoder_block(u4, diff_c3, 128)
    u2 = decoder_block(u3, diff_c2, 64)
    u1 = decoder_block(u2, diff_c1, 32)

    outputs = layers.Conv2D(num_change_classes, (1, 1), activation='softmax', name='change_output')(u1)
    model = Model(inputs=[input_t1, input_t2], outputs=outputs, name='Pseudo_Siamese_CD')
    return model


# --- 4. 权重迁移 (保持不变) ---

def transfer_weights(cd_model, lulc_weights_path):
    if not os.path.exists(lulc_weights_path):
        print(f"❌ 警告：LULC 权重文件不存在于 {lulc_weights_path}")
        return cd_model

    try:
        temp_lulc_model = tf.keras.models.load_model(lulc_weights_path, compile=False)
    except Exception as e:
        print(f"❌ 错误：加载 LULC 权重失败：{e}")
        return cd_model

    print("✅ LULC 预训练权重已加载到临时模型。")

    for lulc_layer in temp_lulc_model.layers:
        weights = lulc_layer.get_weights()
        if not weights: continue

        if lulc_layer.name.startswith(('conv', 'bn', 'pool')) and 't1' not in lulc_layer.name:
            t1_layer_name = lulc_layer.name
            if 'pool' not in lulc_layer.name:
                t1_layer_name = lulc_layer.name.replace('_a', '_a_t1').replace('_b', '_b_t1')
            else:
                 t1_layer_name = lulc_layer.name + '_t1'

            try:
                cd_model.get_layer(t1_layer_name).set_weights(weights)
                cd_model.get_layer(t1_layer_name.replace('_t1', '_t2')).set_weights(weights)
            except (ValueError, KeyError):
                pass

    print("✅ 权重迁移完成：LULC 编码器权重已成功赋给 Pseudo-Siamese 模型的 T1/T2 编码器。")
    del temp_lulc_model
    return cd_model


# --- 5. 变化检测数据加载器 (核心逻辑：已修复 PNG 和路径解码) ---

def create_change_map_label(label1_path, label2_path):
    """
    读取 LULC 标签，计算变化，并将其映射到我们的 4 个目标类别。
    参数 label1_path, label2_path 必须是标准 Python 字符串。
    """
    WATER_CLASS_ID = 4
    VEG_CLASS_IDS = [3, 5]

    # 🚨 使用 cv2 读取 PNG 标签（灰度图）
    L1 = cv2.imread(label1_path, cv2.IMREAD_GRAYSCALE)
    L2 = cv2.imread(label2_path, cv2.IMREAD_GRAYSCALE)

    if L1 is None or L2 is None or L1.shape != L2.shape:
        # 抛出错误以中断 tf.py_function
        raise ValueError(f"LULC 标签加载失败或尺寸不匹配。路径: {label1_path}, {label2_path}")

    CM = np.full_like(L1, 3, dtype=np.int32)

    CM[L1 == L2] = 0
    flood_mask = (L2 == WATER_CLASS_ID) & (L1 != WATER_CLASS_ID)
    CM[flood_mask] = 1
    veg_mask = np.isin(L1, VEG_CLASS_IDS)
    not_veg_mask_l2 = ~np.isin(L2, VEG_CLASS_IDS)
    destruct_mask = veg_mask & not_veg_mask_l2 & (L1 != L2)
    CM[destruct_mask] = 2

    return tf.keras.utils.to_categorical(CM, num_classes=NUM_CHANGE_CLASSES).astype(np.float32)


def load_numpy_arrays(im1_fp_str, im2_fp_str, label1_fp_str, label2_fp_str):
    # 🚨 路径解码修复：在传入 cv2 和 create_change_map_label 之前，显式解码所有 Tensor
    im1_fp_str_decoded = im1_fp_str.numpy().decode('utf-8')
    im2_fp_str_decoded = im2_fp_str.numpy().decode('utf-8')
    label1_fp_str_decoded = label1_fp_str.numpy().decode('utf-8')
    label2_fp_str_decoded = label2_fp_str.numpy().decode('utf-8')

    # 图像加载和归一化 (使用解码后的路径)
    im1 = cv2.cvtColor(cv2.imread(im1_fp_str_decoded, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0
    im2 = cv2.cvtColor(cv2.imread(im2_fp_str_decoded, cv2.IMREAD_COLOR), cv2.COLOR_BGR2RGB).astype(np.float32) / 255.0

    # 生成变化标签 (使用解码后的路径)
    Y = create_change_map_label(label1_fp_str_decoded, label2_fp_str_decoded)

    return im1, im2, Y

@tf.function(input_signature=[tf.TensorSpec(None, tf.string), tf.TensorSpec(None, tf.string), tf.TensorSpec(None, tf.string), tf.TensorSpec(None, tf.string)])
def load_cd_data_wrapper(im1_fp, im2_fp, label1_fp, label2_fp):

    X1, X2, Y = tf.py_function(
        load_numpy_arrays, [im1_fp, im2_fp, label1_fp, label2_fp], [tf.float32, tf.float32, tf.float32]
    )
    # 确保输出的形状是固定的，否则 tf.data.Dataset 会报错
    X1.set_shape(INPUT_SHAPE)
    X2.set_shape(INPUT_SHAPE)
    Y.set_shape((IMG_HEIGHT, IMG_WIDTH, NUM_CHANGE_CLASSES))
    return (X1, X2), Y


def create_cd_dataset(batch_size, is_training):
    # 收集文件路径，逻辑不变
    img_files = glob.glob(os.path.join(IM1_DIR, '*.png'))
    patch_paths = []

    for img_path_t1 in img_files:
        file_id = os.path.basename(img_path_t1)
        path_t2 = os.path.join(IM2_DIR, file_id)
        path_l1 = os.path.join(LABEL1_DIR, file_id) # .png
        path_l2 = os.path.join(LABEL2_DIR, file_id) # .png

        if os.path.exists(path_t2) and os.path.exists(path_l1) and os.path.exists(path_l2):
             patch_paths.append((img_path_t1, path_t2, path_l1, path_l2))

    if not patch_paths:
        raise ValueError("未能找到匹配的 T1/T2/L1/L2 图像对，请检查路径和文件格式。")

    np.random.shuffle(patch_paths)
    split_idx = int(len(patch_paths) * 0.95)

    current_paths = patch_paths[:split_idx] if is_training else patch_paths[split_idx:]

    paths_tuple = tuple([p[i] for p in current_paths] for i in range(4))
    dataset = tf.data.Dataset.from_tensor_slices(paths_tuple)

    if is_training:
        dataset = dataset.shuffle(buffer_size=min(len(current_paths), 5000))

    dataset = dataset.map(load_cd_data_wrapper, num_parallel_calls=tf.data.AUTOTUNE)

    # 确保 map 和 batch 正常工作
    dataset = dataset.batch(batch_size)
    dataset = dataset.prefetch(tf.data.AUTOTUNE)

    return dataset, len(current_paths)


# --- 6. 主运行函数 ---

def run_change_detection_finetuning():
    print("\n--- 阶段 I: 数据集准备 (SECOND Changes) ---")

    try:
        train_dataset, num_train = create_cd_dataset(BATCH_SIZE, is_training=True)
        val_dataset, num_val = create_cd_dataset(BATCH_SIZE, is_training=False)

        print(f"训练样本总数: {num_train}, 验证样本总数: {num_val}")
        if num_train == 0 or num_val == 0:
            print("❌ 错误：训练集或验证集样本数为零。请检查文件是否存在。")
            return

    except ValueError as e:
        print(f"❌ 数据集加载失败: {e}")
        return

    print("\n--- 阶段 II: 模型构建与权重迁移 ---")

    cd_model = build_pseudo_siamese_unet(INPUT_SHAPE, NUM_CHANGE_CLASSES)

    cd_model = transfer_weights(cd_model, LULC_WEIGHTS_PATH)

    # 冻结编码器层
    for layer in cd_model.layers:
        if 't1' in layer.name or 't2' in layer.name or 'bottleneck' in layer.name:
            layer.trainable = False

    cd_model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE),
        loss='categorical_crossentropy',
        metrics=['accuracy', tf.keras.metrics.MeanIoU(num_classes=NUM_CHANGE_CLASSES)]
    )

    # 模型检查点保存到 Drive
    cd_checkpoint_callback = ModelCheckpoint(
        filepath=CD_WEIGHTS_PATH, monitor='val_mean_io_u', mode='max', save_best_only=True, verbose=1
    )
    print(f"变化检测权重将保存到 Drive: {CD_WEIGHTS_PATH}")

    print(f"\n--- 阶段 III: 开始变化检测微调 (目标: {EPOCHS} 个 Epoch, 只训练解码器) ---")

    cd_model.fit(
        train_dataset,
        epochs=EPOCHS,
        validation_data=val_dataset,
        callbacks=[cd_checkpoint_callback],
        verbose=1
    )

    print("\n🎉 变化检测微调完成！")

if __name__ == '__main__':
    run_change_detection_finetuning()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ✅ Google Drive 挂载成功。
#
# --- 阶段 I: 数据集准备 (SECOND Changes) ---
# 训练样本总数: 2819, 验证样本总数: 149
#
# --- 阶段 II: 模型构建与权重迁移 ---
# ✅ LULC 预训练权重已加载到临时模型。
# ✅ 权重迁移完成：LULC 编码器权重已成功赋给 Pseudo-Siamese 模型的 T1/T2 编码器。
# 变化检测权重将保存到 Drive: /content/drive/MyDrive/LULC_Pretrain_Weights/best_cd_finetune_weights.h5
#
# --- 阶段 III: 开始变化检测微调 (目标: 10 个 Epoch, 只训练解码器) ---
# Epoch 1/10
#  82/705 ━━━━━━━━━━━━━━━━━━━━ 3:55 378ms/step - accuracy: 0.2872 - loss: 1.7967 - mean_io_u_2: 0.3750
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-4179284716.py in <cell line: 0>()
#     292
#     293 if __name__ == '__main__':
# --> 294     run_change_detection_finetuning()
#
# /tmp/ipython-input-4179284716.py in run_change_detection_finetuning()
#     281     print(f"\n--- 阶段 III: 开始变化检测微调 (目标: {EPOCHS} 个 Epoch, 只训练解码器) ---")
#     282
# --> 283     cd_model.fit(
#     284         train_dataset,
#     285         epochs=EPOCHS,
#
# /usr/local/lib/python3.12/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     115         filtered_tb = None
#     116         try:
# --> 117             return fn(*args, **kwargs)
#     118         except Exception as e:
#     119             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.12/dist-packages/keras/src/backend/tensorflow/trainer.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     376                     callbacks.on_train_batch_begin(step)
#     377                     logs = self.train_function(iterator)
# --> 378                     callbacks.on_train_batch_end(step, logs)
#     379                     if self.stop_training:
#     380                         break
#
# /usr/local/lib/python3.12/dist-packages/keras/src/callbacks/callback_list.py in on_train_batch_end(self, batch, logs)
#     166             self._on_batch_end(batch, logs)
#     167
# --> 168     def on_train_batch_end(self, batch, logs=None):
#     169         if self._async_train:
#     170             self._async_dispatch(self._on_train_batch_end, batch, logs)
#
# KeyboardInterrupt:
